# %%
import pandas   as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
algae_data = pd.read_csv('C:\\programmer_shit\\data_salo_files\\stepic\\algae.csv')

# %%
algae_data[algae_data["genus"] == "Fucus"]["alanin"]
# Out:
# 0    3.711498
# 2    0.346431
# 3    6.641303
# Name: alanin, dtype: float64

# %%
algae_data.groupby(['genus'])['alanin'].describe()
# Out:
#              count      mean       std       min       25%       50%  \
# genus
# Ascophyllum    1.0  0.875429       NaN  0.875429  0.875429  0.875429
# Cladophora     3.0  3.997055  2.657050  1.648450  2.555071  3.461692
# Fucus          3.0  3.566411  3.149943  0.346431  2.028965  3.711498
# Palmaria       1.0  3.176440       NaN  3.176440  3.176440  3.176440
# Saccharina     2.0  3.524207  3.208789  1.255251  2.389729  3.524207
#
#                   75%       max
# genus
# Ascophyllum  0.875429  0.875429
# Cladophora   5.171358  6.881024
# Fucus        5.176401  6.641303
# Palmaria     3.176440  3.176440
# Saccharina   4.658685  5.793163

# %%
a = algae_data.groupby(['group'])["glucose"].describe()
a["max"] - a["min"]
# Out:
# group
# brown    3.740495
# green    1.026753
# red      0.000000
# dtype: float64

# %%
algae_data.groupby('group').aggregate(['count', 'var', np.ptp])
# Out:
#       sucrose                     alanin                     citrate  \
#         count       var       ptp  count       var       ptp   count
# group
# brown       6  5.459098  5.189345      6  7.220351  6.294872       6
# green       3  2.672626  3.259662      3  7.059917  5.232574       3
# red         1       NaN  0.000000      1       NaN  0.000000       1
#
#                           glucose                     oleic_acid            \
#             var       ptp   count       var       ptp      count       var
# group
# brown  5.468942  5.351686       6  1.767756  3.740495          6  4.385233
# green  3.950113  3.857763       3  0.266265  1.026753          3  0.540388
# red         NaN  0.000000       1       NaN  0.000000          1       NaN
#
#
#             ptp
# group
# brown  6.100592
# green  1.396502
# red    0.000000

# %%
import pandas   as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
student_data = pd.read_csv('C:\\programmer_shit\\data_salo_files\\StudentsPerformance.csv')  

student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_data["math score"].hist()
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x = "math score", y = "reading score",hue = "race/ethnicity", data = student_data, fit_reg = False)

# %%
genome_matrix = pd.read_csv('C:\\programmer_shit\\data_salo_files\\stepic\\genome_matrix.csv', index_col = 0)  

genome_matrix
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(data = genome_matrix, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)
g
# Out:
# <AxesSubplot:>

# %%
iris = pd.read_csv('C:\\programmer_shit\\data_salo_files\\stepic\\iris.csv',  index_col = 0)  
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data = iris)

# %%
submissions_data_train = pd.read_csv('C:\\programmer_shit\\data_salo_files\\stepic\\submissions_data_train.csv')  
submissions_data_train
# Out:
#         step_id   timestamp submission_status  user_id
# 0         31971  1434349275           correct    15853
# 1         31972  1434348300           correct    15853
# 2         31972  1478852149             wrong    15853
# 3         31972  1478852164           correct    15853
# 4         31976  1434348123             wrong    15853
# ...         ...         ...               ...      ...
# 509099   120745  1501946959             wrong     2615
# 509100   120745  1503059927           correct    13177
# 509101   120745  1506348153             wrong    15253
# 509102   120745  1523035316             wrong     1424
# 509103   120745  1523382825             wrong     9422
#
# [509104 rows x 4 columns]

# %%
event_data_train = pd.read_csv('C:\\programmer_shit\\data_salo_files\\stepic\\event_data_train.csv')  
event_data_train
# Out:
#          step_id   timestamp      action  user_id
# 0          32815  1434340848      viewed    17632
# 1          32815  1434340848      passed    17632
# 2          32815  1434340848  discovered    17632
# 3          32811  1434340895  discovered    17632
# 4          32811  1434340895      viewed    17632
# ...          ...         ...         ...      ...
# 3480698    33375  1526772685      viewed    11677
# 3480699    32815  1526772750      viewed     5198
# 3480700    32815  1526772750  discovered     5198
# 3480701    32815  1526772750      passed     5198
# 3480702    33892  1526772811      viewed    18526
#
# [3480703 rows x 4 columns]

# %%
event_data_train["datetime"] = pd.to_datetime(event_data_train["timestamp"], unit = 's')
event_data_train["day"] = event_data_train["datetime"].dt.date
event_data_train
# Out:
#          step_id   timestamp      action  user_id            datetime  \
# 0          32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1          32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2          32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3          32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4          32811  1434340895      viewed    17632 2015-06-15 04:01:35
# ...          ...         ...         ...      ...                 ...
# 3480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 3480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 3480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
#                 day
# 0        2015-06-15
# 1        2015-06-15
# 2        2015-06-15
# 3        2015-06-15
# ...

# %%
event_data_train[event_data_train["action"] == "discovered"].groupby('day').user_id.nunique().plot(figsize=(20,10))
# Out:
# 0

# %%
# excludes users who have not taken any steps
# event_data_train[event_data_train["action"] == "passed"].groupby('user_id', as_index=False)["step_id"].agg({"step_id" : "count"}).step_id.hist()
event_data_train.pivot_table(index = "user_id", columns = "action", values = "step_id", aggfunc = "count", fill_value = 0).reset_index().discovered.hist()
# Out:
# <AxesSubplot:>

# %%
count_correct = submissions_data_train.step_id.nunique()



p = submissions_data_train.pivot_table(index = "user_id", columns = "submission_status", values = "step_id", aggfunc = "count", fill_value = 0).reset_index()
p["correct+wrong"] = p["correct"] + p["wrong"]

new_df = submissions_data_train.pivot_table(index='user_id', columns='submission_status',values='step_id', aggfunc='count')

new_df[new_df['correct'] == new_df['correct'].max()]
m = p["correct"].max()
p[p["correct"] == m]
# Out:
# submission_status  user_id  correct  wrong  correct+wrong
# 439                   1046      421    513            934

# %%
gap_data = event_data_train[["user_id", "timestamp", "day"]].drop_duplicates(subset = ["user_id", "day"]).groupby("user_id")["timestamp"]\
.apply(list).apply(np.diff).values

gap_data = pd.Series(np.concatenate(gap_data, axis = 0)) / (24* 60 * 60)
gap_data.describe()
# Out:
# count    97872.000000
# mean        14.299616
# std         58.586403
# min          0.000301
# 25%          0.970923
# 50%          1.315480
# 75%          4.147341
# max       1053.684606
# dtype: float64

# %%
submissions_data_train.groupby("user_id").count()["submission_status"].sort_values()
# Out:
# user_id
# 6345        1
# 11363       1
# 21554       1
# 21532       1
# 21506       1
#          ...
# 643       888
# 14454     920
# 1046      934
# 3643      948
# 12265    1051
# Name: submission_status, Length: 9940, dtype: int64

# %%
# who is maded some actions every month
# event_data_train["year-month"] = event_data_train["day"]

a = event_data_train["datetime"].dt


y= a.year 
y = y.astype(str)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f1eae4bebe4d> in <module>
# ----> 1 dogs = pd.read_csv("https://stepik.org/media/attachments/course/4852/dogs.csv")
#       2 dogs = dogs.drop('Unnamed: 0', axis=1)
#       3
#       4 dogs_X = dogs.iloc[:, :3]
#       5 dogs_y = dogs.iloc[:, 3]
#
# NameError: name 'pd' is not defined
