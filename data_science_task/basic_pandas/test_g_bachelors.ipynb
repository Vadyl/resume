# %%
import pandas   as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
bachelors_data = pd.read_csv('C:\\programmer_shit\\goshko_csv_files\\percent-bachelors-degrees-women-usa.csv')  

bachelors_data.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
# 1
b = bachelors_data[5:41:10] 
a = bachelors_data[bachelors_data.Year == 2010] 
right_years = pd.merge(b, a, how='outer')
r = right_years[["Agriculture","Computer Science", "Health Professions"]]

r.boxplot()
# Out:
# <AxesSubplot:>

# %%
# 2
b = bachelors_data[:41:10] 
b
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 0   1970     4.229798     11.921005                 59.7  29.088363
# 10  1980    30.759390     28.080381                 63.4  43.999257
# 20  1990    32.703444     40.824047                 62.6  50.818094
# 30  2000    45.057766     40.023585                 59.2  59.389857
# 40  2010    48.730042     42.066721                 61.3  59.010255
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 0    9.064439                           35.3              13.6  74.535328
# 10  36.765725                           54.7              32.5  74.981032
# 20  47.200851                           60.8              29.4  78.866859
# 30  49.803616                           61.9              27.7  76.692143
# 40  48.757988                           62.5              17.6  79.618625
#
#     Engineering    English  Foreign Languages  Health Professions  \
# ...

# %%
b = b.drop("Year", axis = 1)
mins = []
maxs = []
for i in range(5):
    mins.append( b.iloc[i].idxmin())
    maxs.append( b.iloc[i].idxmax())
    
print("maxs: " , maxs)
print("mins: " , mins)
# Out:
# maxs:  ['Health Professions', 'Health Professions', 'Health Professions', 'Health Professions', 'Health Professions']
# mins:  ['Engineering', 'Engineering', 'Engineering', 'Engineering', 'Engineering']
