# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
# %matplotlib inline

from graphviz  import Source
from IPython.display import SVG, display, HTML
style = "<style>svg{width: 50% !important; height: 50% !important;} </style>"

# %%
dogs_n_cats = pd.read_csv('C:\\programmer_shit\\data_salo_files\\stepic\\dogs_n_cats.csv' )
dogs_n_cats
# Out:
#      Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0       15    18.0         1        1                   0  собачка
# 1       20    24.0         1        0                   0  собачка
# 2       34    40.8         1        1                   0  собачка
# 3       26    31.2         1        1                   0  собачка
# 4       16    19.2         1        1                   0  собачка
# ..     ...     ...       ...      ...                 ...      ...
# 995      8     3.2         1        0                   1    котик
# 996      7     2.8         1        0                   1    котик
# 997      6     2.4         1        0                   1    котик
# 998      7     2.8         1        0                   1    котик
# 999     11     4.4         1        0                   1    котик
#
# [1000 rows x 6 columns]

# %%
X = dogs_n_cats
X = pd.get_dummies(X)
print(X)
y = X.Вид_собачка
X = X.drop(["Вид_собачка", "Вид_котик"] , axis = 1)
X
# Out:
#      Длина  Высота  Шерстист  Гавкает  Лазает по деревьям  Вид_котик  \
# 0       15    18.0         1        1                   0          0
# 1       20    24.0         1        0                   0          0
# 2       34    40.8         1        1                   0          0
# 3       26    31.2         1        1                   0          0
# 4       16    19.2         1        1                   0          0
# ..     ...     ...       ...      ...                 ...        ...
# 995      8     3.2         1        0                   1          1
# 996      7     2.8         1        0                   1          1
# 997      6     2.4         1        0                   1          1
# 998      7     2.8         1        0                   1          1
# 999     11     4.4         1        0                   1          1
#
#      Вид_собачка
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# ...

# %%
clf = tree.DecisionTreeClassifier(criterion="entropy" , max_depth =4)
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
graph = Source(tree.export_graphviz(clf, out_file=None, feature_names=list(X),
class_names=['Кот', 'Собака'], filled=True))
display(SVG(graph.pipe(format='svg')))

# %%
dataset_209691_15 = pd.read_json('C:\\programmer_shit\\data_salo_files\\stepic\\dataset_209691_15 (2).json' )

dataset_209691_15
# Out:
#     Длина  Высота  Шерстист  Гавкает  Лазает по деревьям
# 0      17    20.4         1        0                   0
# 1      29    34.8         1        1                   0
# 2      20    24.0         1        1                   0
# 3      15    18.0         1        0                   0
# 4      15    18.0         1        1                   0
# ..    ...     ...       ...      ...                 ...
# 95      5     2.0         1        0                   1
# 96      6     2.4         1        0                   1
# 97      6     2.4         1        0                   1
# 98      8     3.2         1        0                   1
# 99     10     4.0         1        0                   1
#
# [100 rows x 5 columns]

# %%
a = clf.predict(dataset_209691_15)
a = np.array(a)
s = np.sum(a)
c = np.size(a)
res = s / c
res
# Out:
# 0.59
